# %%
import sys
sys.path.append('../src')

import pandas as pd
from config import TRAIN_CSV, TARGET_COL, NUMERIC_FEATURES, CATEGORICAL_FEATURES

df = pd.read_csv(TRAIN_CSV)
print(f'{len(df):,} rows, {df.shape[1]} columns')
df.head()

# %%
# Missingness
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False)

# %%
# Target class balance
df[TARGET_COL].value_counts(normalize=True) * 100

# %%
# Numeric feature correlations
df[NUMERIC_FEATURES].corr()

# %%
# Non-monotonic stress_level effect (Figure 4 in the report)
pd.crosstab(df['stress_level'], df[TARGET_COL], normalize='index') * 100
